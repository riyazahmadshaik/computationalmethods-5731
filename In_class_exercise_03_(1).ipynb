# %% [markdown]
# <a href="https://colab.research.google.com/github/riyazahmadshaik/computationalmethods-5731/blob/master/In_class_exercise_03_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (9/16/2020, 20 points in total)

# %% [markdown]
# The purpose of this exercise is to under users' information needs, then collect the data for analysis.

# %% [markdown]
# Question 1 (8 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:


The interesting research which I had in my mind when doing this web scrapping was to scrap the best places to visit in India and the Information about the places to give the tourist meaningful insights. There were many data to 
anlayse, the data gives informatiion about the place with the state name. The website which I scrapped was holidify using the BeautifulSoup python package for parsing HTML and XML documents.


'''

# %% [markdown]
# Question 2 (12 points): Write python code to collect 500 items of the data you plan to collect above.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
import requests
from bs4 import BeautifulSoup
link = "https://www.holidify.com/explore/"
P_link = requests.get(link)
print(P_link)

html = P_link.text
soup = BeautifulSoup(html, "html.parser")
# Out:
# <Response [200]>

# %%
containers = P_soup.findAll("div", {"class" : "col-12 col-md-6 pr-lg-3 pl-md-3 pl-lg-0 result"})
print(len(containers))
# Out:
# 60

# %%
def places(soup):
  names=[]
  for div in soup.find_all(name="div",attrs={"class":"col-12 col-md-6 pr-lg-3 pl-md-3 pl-lg-0 result"}):
    for i in div.find_all(name="div",attrs={"class":"card content-card"}):
      for h in i.find_all(name="h3",attrs={"class":"card-heading"}):
        names.append(h.text)
  return names
p=places(soup)

def information(soup):
  about=[]
  for div in soup.find_all(name="div",attrs={"class":"col-12 col-md-6 pr-lg-3 pl-md-3 pl-lg-0 result"}):
    for i in div.find_all(name="div",attrs={"class":"card content-card"}):
      for j in i.find_all(name="div",attrs={"class":"card-body"}):
        for p in j.find_all(name="p",attrs={"class":"card-text"}):
          about.append(p.text)
  return about

i=information(soup)


data=list(zip(p,i))
df=pd.DataFrame(data,columns=['Place','About the place'])
df
# Out:
#                                          Place                                    About the place
# 0                          1. Gangtok, Sikkim    Incredibly alluring, pleasantly boisterous an...
# 1                  2. Darjeeling, West Bengal    Jaw-dropping locales, mesmerising sunrises, t...
# 2                       3. Udaipur, Rajasthan    Udaipur, also known as the City of Lakes, is ...
# 3             4. Mcleodganj, Himachal Pradesh    Mcleodganj is a hill station near Dharamshala...
# 4                           5. Munnar, Kerala    Munnar is a popular hill-station of Kerala pe...
# 5                         6. Coorg, Karnataka    Located amidst imposing mountains in Karnatak...
# 6                 7. Manali, Himachal Pradesh    Nestled in between the snow-capped slopes of ...
# 7                         8. Ooty, Tamil Nadu    Nestled amidst Nilgiri hills, Ooty, also know...
# 8                  9. Kasol, Himachal Pradesh    Kasol is a quaint little village in Himachal ...
# ...
