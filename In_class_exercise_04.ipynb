# %% [markdown]
# <a href="https://colab.research.google.com/github/riyazahmadshaik/computationalmethods-5731/blob/master/In_class_exercise_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The fourth in-class-exercise (20 points in total)**

# %% [markdown]
# # 1. Text Data Preprocessing
#
# Here is a [legal case](https://github.com/unt-iialab/INFO5731_FALL2020/blob/master/In_class_exercise/01-05-1%20%20Adams%20v%20Tanner.txt) we collected from westlaw, please follow the steps we mentioned in lesson 5 to clean the data:
#
#
#
# ## 1.1 Basic feature extraction using text data (4 points)
#
# *   Number of sentences
# *   Number of words
# *   Number of characters
# *   Average word length
# *   Number of stopwords
# *   Number of special characters
# *   Number of numerics
# *   Number of uppercase words
#
# ## 1.2 Basic Text Pre-processing of text data (4 points)
#
# *   Lower casing
# *   Punctuation removal
# *   Stopwords removal
# *   Frequent words removal
# *   Rare words removal
# *   Spelling correction
# *   Tokenization
# *   Stemming
# *   Lemmatization
#
# ## 1.3 Save all the **clean sentences** to a **csv file** (one column, each raw is a sentence) after finishing all the steps above. (4 points)
#
#
# ## 1.4 Advance Text Processing (Extra credit: 4 points)
#
# *   Calculate the term frequency of all the terms.
# *   Print out top 10 1-gram, top 10 2-grams, and top 10 3-grams terms as features.

# %%
# Write your code here

#readingthefile
f = open("riyazinclass4.txt","r")
print(f.read())
# Out:
# 5 Ala. 740
# Supreme Court of Alabama.
# ADAMS
# v.
# TANNER AND HORTON.
# June Term, 1843.
# Synopsis
# WRIT of Error to the Circuit Court of Sumter.
#
#
#
# West Headnotes (2)
#
#
# [1]
# Chattel Mortgages
# Crops
# A growing crop has such an existence as to be the subject-matter of a mortgage or other contract which passes an interest to vest in possession, either immediately or at a future time.
# 4 Cases that cite this headnote
#
# [2]
# Creditors’ Remedies
# Lien and Priority
# Under St.1821, prohibiting a levy on a crop until it has been gathered, no lien attaches in favor of a fi. fa. on a growing crop, nor does such lien attach until after the crop has been gathered.
# 5 Cases that cite this headnote
#
# ...

# %%
import requests
url = "https://raw.githubusercontent.com/riyazahmadshaik/computationalmethods-5731/master/Inclass4.txt"
website = requests.get(url)
d = website.text
print(d)
# Out:
# 5 Ala. 740
# Supreme Court of Alabama.
# ADAMS
# v.
# TANNER AND HORTON.
# June Term, 1843.
# Synopsis
# WRIT of Error to the Circuit Court of Sumter.
#
#
#
# West Headnotes (2)
#
#
# [1]
# Chattel Mortgages
# Crops
# A growing crop has such an existence as to be the subject-matter of a mortgage or other contract which passes an interest to vest in possession, either immediately or at a future time.
# 4 Cases that cite this headnote
#
# [2]
# Creditors’ Remedies
# Lien and Priority
# Under St.1821, prohibiting a levy on a crop until it has been gathered, no lien attaches in favor of a fi. fa. on a growing crop, nor does such lien attach until after the crop has been gathered.
# 5 Cases that cite this headnote
#
# ...

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#sentences
print(len(sent_tokenize(d)))
# Out:
# 173

# %%
#word
print(len(word_tokenize(d)))
# Out:
# 4368

# %%
#characters
print(len(d))
# Out:
# 20613

# %%
#average
a = word_tokenize(d)
b = []
for i in a:
  b.append(len(a))
print("The average is:",sum(b)/len(a))
# Out:
# The average is: 4368.0

# %%
#stopwords
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stopword = stopwords.words('english')
stop=[]
for x in a:
  if x in stopword:
    stop.append(x)
print(len(stop))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1734

# %%
import re
q = len(d)-len(re.findall('[\w]',d))
q
# Out:
# 4710

# %%
#numerics
g=[]
for i in d:
  if i.isdigit():
    g.append(i)
print(len(g))
# Out:
# 356

# %%
#uppercase
upper = []
for x in a:
  if x.isupper():
    upper.append(x)
print(len(upper))
# Out:
# 84

# %%
#lower case
clean = d.lower()
clean1= re.sub(r'[^\w\s]','',clean)

# %%
clean2=''
split = clean1.split()
for x in split:
  for y in x.split():
    if not y in stop:
      clean2 = clean2 + '' + y 
    clean2 = clean2 + '\n'
print(clean2)
# Out:
# 5
# ala
# 740
# supreme
# court
#
# alabama
# adams
# v
# tanner
#
# horton
# june
# term
# 1843
# synopsis
# writ
#
# error
#
#
# circuit
# court
#
# sumter
# west
# headnotes
# 2
# 1
# chattel
# mortgages
# crops
#
# growing
# crop
#
#
#
# existence
#
#
#
#
# subjectmatter
#
#
# mortgage
#
#
# contract
#
# passes
#
# interest
#
# vest
#
# possession
# either
# immediately
#
#
#
# future
# time
# 4
# cases
#
# cite
#
# headnote
# 2
# creditors
# remedies
# lien
#
# priority
#
# st1821
# prohibiting
#
# levy
#
#
# crop
#
#
#
#
# gathered
#
# lien
# attaches
#
# favor
#
#
# fi
# fa
#
#
# growing
# crop
#
#
#
# lien
# attach
#
#
#
# crop
#
#
# gathered
# 5
# cases
#
# cite
#
# headnote
# 1
#
#
#
# trial
#
#
# right
#
# property
#
#
# statute
#
# november
# 1840
#
# execution
# issued
#
#
# circuit
# court
#
# sumter
#
#
# suit
#
#
# plaintiff
#
# error
# requiring
#
# sheriff
#
#
# county
#
# make
#
#
# goods
# c
#
# allen
# harrison
#
# others
#
# sum
#
# thirtyseven
# hundred
#
# ...

# %%
#word removal
import pandas as pd
f = pd.Series(clean2.split()).value_counts()[:10]
f
# Out:
# execution    50
# crop         49
# lien         25
# levy         25
# v            22
# claimants    22
# right        21
# case         21
# court        20
# gathered     19
# dtype: int64

# %%
clean3 = '' 
s = list(f.index)
for x in clean2.split('\n'):
  for y in x.split():
    if not y in f:
      clean3 = clean3 + '' + y 
    clean3 = clean3 + '\n'
print(clean3)
# Out:
# 5
# ala
# 740
# supreme
#
# alabama
# adams
#
# tanner
# horton
# june
# term
# 1843
# synopsis
# writ
# error
# circuit
#
# sumter
# west
# headnotes
# 2
# 1
# chattel
# mortgages
# crops
# growing
#
# existence
# subjectmatter
# mortgage
# contract
# passes
# interest
# vest
# possession
# either
# immediately
# future
# time
# 4
# cases
# cite
# headnote
# 2
# creditors
# remedies
#
# priority
# st1821
# prohibiting
#
#
#
#
# attaches
# favor
# fi
# fa
# growing
#
#
# attach
#
#
# 5
# cases
# cite
# headnote
# 1
# trial
#
# property
# statute
# november
# 1840
#
# issued
# circuit
#
# sumter
# suit
# plaintiff
# error
# requiring
# sheriff
# county
# make
# goods
# c
# allen
# harrison
# others
# sum
# thirtyseven
# hundred
# seventyseven
# 80100
# dollars
# besides
# costs
#
# levied
# thirty
# bales
# cotton
# property
# allen
# harrison
# claimed
# bond
# given
# try
#
# issue
# made
# try
# question
# liability
# cotton
# plaintiffs
#
# submitted
# jury
# trial
# bill
# ...

# %%
r = pd.Series(clean2.split()).value_counts()[-20:]
r
# Out:
# sum              1
# trespass         1
# bond             1
# far              1
# claims           1
# united           1
# six              1
# r                1
# g                1
# goods            1
# propriety        1
# stands           1
# transferrable    1
# taking           1
# yield            1
# 693              1
# 741              1
# contradict       1
# dowl             1
# jones            1
# dtype: int64

# %%
clean4 = ''
for x in clean3.split('\n'):
  for y in x.split():
    if not y in f:
      clean4 = clean4 + '' + y 
    clean4 = clean4 + '\n'
print(clean4)
# Out:
# 5
# ala
# 740
# supreme
# alabama
# adams
# tanner
# horton
# june
# term
# 1843
# synopsis
# writ
# error
# circuit
# sumter
# west
# headnotes
# 2
# 1
# chattel
# mortgages
# crops
# growing
# existence
# subjectmatter
# mortgage
# contract
# passes
# interest
# vest
# possession
# either
# immediately
# future
# time
# 4
# cases
# cite
# headnote
# 2
# creditors
# remedies
# priority
# st1821
# prohibiting
# attaches
# favor
# fi
# fa
# growing
# attach
# 5
# cases
# cite
# headnote
# 1
# trial
# property
# statute
# november
# 1840
# issued
# circuit
# sumter
# suit
# plaintiff
# error
# requiring
# sheriff
# county
# make
# goods
# c
# allen
# harrison
# others
# sum
# thirtyseven
# hundred
# seventyseven
# 80100
# dollars
# besides
# costs
# levied
# thirty
# bales
# cotton
# property
# allen
# harrison
# claimed
# bond
# given
# try
# issue
# made
# try
# question
# liability
# cotton
# plaintiffs
# submitted
# jury
# trial
# bill
# exceptions
# sealed
# instance
# plaintiff
# ...

# %%
from textblob import TextBlob

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer
clean5=''
t=PorterStemmer()
for x in clean4.split('\n'):
  for y in x.split():
    clean5 = clean5 + '' + t.stem(y)
  clean5 = clean5 + '\n'
print(clean5)
# Out:
# 5
# ala
# 740
# suprem
# alabama
# adam
# tanner
# horton
# june
# term
# 1843
# synopsi
# writ
# error
# circuit
# sumter
# west
# headnot
# 2
# 1
# chattel
# mortgag
# crop
# grow
# exist
# subjectmatt
# mortgag
# contract
# pass
# interest
# vest
# possess
# either
# immedi
# futur
# time
# 4
# case
# cite
# headnot
# 2
# creditor
# remedi
# prioriti
# st1821
# prohibit
# attach
# favor
# fi
# fa
# grow
# attach
# 5
# case
# cite
# headnot
# 1
# trial
# properti
# statut
# novemb
# 1840
# issu
# circuit
# sumter
# suit
# plaintiff
# error
# requir
# sheriff
# counti
# make
# good
# c
# allen
# harrison
# other
# sum
# thirtyseven
# hundr
# seventyseven
# 80100
# dollar
# besid
# cost
# levi
# thirti
# bale
# cotton
# properti
# allen
# harrison
# claim
# bond
# given
# tri
# issu
# made
# tri
# question
# liabil
# cotton
# plaintiff
# submit
# juri
# trial
# bill
# except
# seal
# instanc
# plaintiff
# plaintiff
# prove
# recov
# judgment
# octob
# 1839
# 741
# issu
# thereon
# ...

# %%
from textblob import Word
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
clean6 = ''
for x in clean5.split('\n'):
  for y in x.split():
    clean6 = clean6 + '' + Word(y).lemmatize()
  clean6=clean + '\n'
print(clean6)
# Out:
# 5 ala. 740
# supreme court of alabama.
# adams
# v.
# tanner and horton.
# june term, 1843.
# synopsis
# writ of error to the circuit court of sumter.
#
#
#
# west headnotes (2)
#
#
# [1]
# chattel mortgages
# crops
# a growing crop has such an existence as to be the subject-matter of a mortgage or other contract which passes an interest to vest in possession, either immediately or at a future time.
# 4 cases that cite this headnote
#
# [2]
# creditors’ remedies
# lien and priority
# under st.1821, prohibiting a levy on a crop until it has been gathered, no lien attaches in favor of a fi. fa. on a growing crop, nor does such lien attach until after the crop has been gathered.
# 5 cases that cite this headnote
#
# ...

# %%
file = open('file.csv','w')
file.write("output")
file.write(clean6)
file.close()

# %%
import pandas as pd
df = pd.read_csv("file.csv",sep='\t')
df
# Out:
#                                                 output
# 0                                           5 ala. 740
# 1                            supreme court of alabama.
# 2                                                adams
# 3                                                   v.
# 4                                   tanner and horton.
# ..                                                 ...
# 143            there are no filings for this citation.
# 144                                 negative treatment
# 145  there are no negative treatment results for th...
# 146                                            history
# 147    there are no history results for this citation.
#
# [148 rows x 1 columns]

# %%
for x in range(10):
  print(TextBlob(df['output'][x]).ngrams(1))
# Out:
# [WordList(['5']), WordList(['ala']), WordList(['740'])]
# [WordList(['supreme']), WordList(['court']), WordList(['of']), WordList(['alabama'])]
# [WordList(['adams'])]
# [WordList(['v'])]
# [WordList(['tanner']), WordList(['and']), WordList(['horton'])]
# [WordList(['june']), WordList(['term']), WordList(['1843'])]
# [WordList(['synopsis'])]
# [WordList(['writ']), WordList(['of']), WordList(['error']), WordList(['to']), WordList(['the']), WordList(['circuit']), WordList(['court']), WordList(['of']), WordList(['sumter'])]
# []
# [WordList(['west']), WordList(['headnotes']), WordList(['2'])]

# %%
for x in range(10):
  print(TextBlob(df['output'][x]).ngrams(2))
# Out:
# [WordList(['5', 'ala']), WordList(['ala', '740'])]
# [WordList(['supreme', 'court']), WordList(['court', 'of']), WordList(['of', 'alabama'])]
# []
# []
# [WordList(['tanner', 'and']), WordList(['and', 'horton'])]
# [WordList(['june', 'term']), WordList(['term', '1843'])]
# []
# [WordList(['writ', 'of']), WordList(['of', 'error']), WordList(['error', 'to']), WordList(['to', 'the']), WordList(['the', 'circuit']), WordList(['circuit', 'court']), WordList(['court', 'of']), WordList(['of', 'sumter'])]
# []
# [WordList(['west', 'headnotes']), WordList(['headnotes', '2'])]

# %%
for x in range(10):
  print(TextBlob(df['output'][x]).ngrams(3))
# Out:
# [WordList(['5', 'ala', '740'])]
# [WordList(['supreme', 'court', 'of']), WordList(['court', 'of', 'alabama'])]
# []
# []
# [WordList(['tanner', 'and', 'horton'])]
# [WordList(['june', 'term', '1843'])]
# []
# [WordList(['writ', 'of', 'error']), WordList(['of', 'error', 'to']), WordList(['error', 'to', 'the']), WordList(['to', 'the', 'circuit']), WordList(['the', 'circuit', 'court']), WordList(['circuit', 'court', 'of']), WordList(['court', 'of', 'sumter'])]
# []
# [WordList(['west', 'headnotes', '2'])]

# %%
t = (df['output']).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
t.columns = ['words','t']
t
# Out:
#           words     t
# 0             5   6.0
# 1          ala.  14.0
# 2           740   1.0
# 3         court  18.0
# 4      alabama.   1.0
# ...         ...   ...
# 1155    render,   1.0
# 1156    filings   2.0
# 1157  citation.   3.0
# 1158   negative   2.0
# 1159    history   2.0
#
# [1160 rows x 2 columns]

# %% [markdown]
# # 2. Python Regular Expression

# %% [markdown]
# ## 2.1 Write a Python program to remove leading zeros from an IP address. (4 points)
#
# ip = "260.08.094.109"

# %%
# Write your code here


def a(ip):
  ip1 = ".".join([str(int(i)) for i in ip.split(".")])
  return ip1;
ip = "260.08.094.109"
print(a(ip))
# Out:
# 260.8.94.109

# %% [markdown]
# ## 2.2 Write a Python Program to extract all the years from the following sentence. (4 points)
#
# sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

# %%
# Write your code here
import re
d = re.findall('(\d{4})', 'The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys soccer team from a flooded cave to the divisive election of President Donald Trump.')
d[:] = [x for x in d if "1000" not in x]
d
# Out:
# ['2010', '2010', '2019']
